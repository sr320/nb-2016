# %% [markdown]
# <img src="http://eagle.fish.washington.edu/cnidarian/skitch/ICSASG_v2_-_Assembly_-_NCBI_1CDBE816.png" alt="ICSASG_v2_-_Assembly_-_NCBI_1CDBE816.png"/>

# %% [markdown]
# <img src="http://eagle.fish.washington.edu/cnidarian/skitch/Index_of__genomes_all_GCA_000233375_4_ICSASG_v2_1CDBE833.png" alt="Index_of__genomes_all_GCA_000233375_4_ICSASG_v2_1CDBE833.png"/>

# %%
# !pwd
# Out:
# /Users/sr320/git-repos/nb-2016/S_salar

# %%
cd /Volumes/web-1/halfshell/working-directory
# Out:
# /Volumes/web-1/halfshell/working-directory
# /Volumes/web-1/halfshell/working-directory

# %%
mkdir 16-05-05

# %%
cd 16-05-05
# Out:
# /Volumes/web-1/halfshell/working-directory/16-05-05
# /Volumes/web-1/halfshell/working-directory/16-05-05

# %%
# !ls
# Out:
# GCA_000233375.4_ICSASG_v2_assembly_report.txt GCA_000233375.4_ICSASG_v2_genomic.gff.gz      README.txt
# GCA_000233375.4_ICSASG_v2_assembly_stats.txt  GCA_000233375.4_ICSASG_v2_rm.out.gz           download
# GCA_000233375.4_ICSASG_v2_genomic.fna.gz      GCA_000233375.4_ICSASG_v2_rm.run
# GCA_000233375.4_ICSASG_v2_genomic.gbff.gz     GCA_000233375.4_ICSASG_v2_wgsmaster.gbff.gz
# GCA_000233375.4_ICSASG_v2_assembly_report.txt GCA_000233375.4_ICSASG_v2_genomic.gff.gz      README.txt
# GCA_000233375.4_ICSASG_v2_assembly_stats.txt  GCA_000233375.4_ICSASG_v2_rm.out.gz           download
# GCA_000233375.4_ICSASG_v2_genomic.fna.gz      GCA_000233375.4_ICSASG_v2_rm.run
# GCA_000233375.4_ICSASG_v2_genomic.gbff.gz     GCA_000233375.4_ICSASG_v2_wgsmaster.gbff.gz

# %%
# !cat README.txt
# Out:
# ################################################################################
# README for ftp://ftp.ncbi.nlm.nih.gov/genomes/genbank/
#            ftp://ftp.ncbi.nlm.nih.gov/genomes/refseq/
#            ftp://ftp.ncbi.nlm.nih.gov/genomes/all/
#
# Last updated: March 14, 2016
# ################################################################################
#
# ...
# Background
# ...
# Sequence data is provided for all single organism genome assemblies that are
# included in NCBI's Assembly resource (www.ncbi.nlm.nih.gov/assembly/).  This
# includes submissions to databases of the International Nucleotide Sequence
# Database Collaboration, which are available in NCBI's GenBank database, as well
# as the subset of those submissions that are included in NCBI's RefSeq Genomes
# project.
#
# Available by anonymous FTP at:
#
#         ftp://ftp.ncbi.nlm.nih.gov/genomes/
#
# Please refer to README files and the FTP FAQ for additional information:
# ...
